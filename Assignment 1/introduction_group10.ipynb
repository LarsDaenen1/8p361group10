# %% [markdown]
# # Assignment 1: Introduction to histopathology image analysis
#
# The goal of this assignment is to define and analyze the problem that you will be working on. In the main project, you will develop a **deep neural network** model that can identify **metastases** in image patches from histological preparations of lymph node tissue from breast cancer patients. Then, you will submit results of the developed model to an open **challenge** competition where it will be compared to models developed by other researchers.
#
# The following three subsections give an introduction to deep learning, medical image analysis challenges/competitions, and detection of lymph node metastases. This very brief text along with the provided references are a good starting point for further exploration these topics.
#
# ### Deep learning for medical image analysis
#
# In the coming decade, artificial intelligence will affect many aspects of human life and society ranging from home automation and self-driving cars to algorithmic detection of “fake news” on social media. This technology will also inevitably influence healthcare and in turn medical imaging. One of the most active fields of research in artificial intelligence is deep machine learning [1][2]. This concept works by learning abstract, hierarchical feature representations of input data that are predictive of a certain target (e.g. a class label in the case of classification). In contrast to classical machine learning methods, deep learning eliminates the step of “manual” feature engineering that is a tedious process and sub-optimal compared with learned representations.
#
# In the field of medical image analysis, the use of deep learning methods has already resulted in notable progress for a variety of tasks. Some of the first applications where automatic methods were shown to outperform medical experts have been in histopathology image analysis [3].
#
#
# ### Medical image analysis challenges
#
# One of the developments that brought about the success of deep learning methods in computer vision was the availability of large, public annotated image datasets. In medical image analysis, this was mirrored in the form of medical image analysis challenges – friendly competitions in which researchers worldwide evaluate their solutions on the same data with the same criteria, in a blinded manner [4]. Organizing a challenge constitutes collecting and publicly distributing a training dataset that can be used to address a specific clinical task (such as detection of lymph node metastases). The ground truth for the testing is set is retained by the organizers of the challenge, which facilitates fair and independent evaluation and comparison of methods. The organization of medical image analysis challenges has had a tremendous impact on the advancement of the state of the art in the field. In the coming decade, such efforts will continue to push the field forward.
#
# For the main project work, you will use a dataset of image patches [9] derived from the CAMELYON16 challenge [3]. This Patch-CAMELYON dataset is itself published as a challenge on the Kaggle platform [10], where you will submit the results of your project work for independent evaluation.
#
# Some other examples of histopathology image analysis challenges organized by our group are AMIDA13 [5] and TUPAC16 [6].
#
# ### Detection of lymph node metastases
#
# The presence of metastases in sentinel axillary lymph nodes is an important component of breast cancer staging [7]. This is evaluated by examination of histological preparations of lymph node tissue by pathologists. The figure below gives an example of a metastasis in lymph node tissue. Although manual assessment by a pathologists is the current standard practice, this procedure is notoriously tedious to perform and can result in missed metastases, which in turn results in suboptimal therapy planning for the patients. The move towards digitalization of histopathology labs with the introduction of whole-slide image scanners [8], has opened the possibility of automating some of the tasks performed by pathologists with the use of image analysis methods. The goal is to have faster, more accurate and more objective analysis of the tissue. Tedious and error prone tasks such as detection of metastases are a very good use case for introduction of automated image analysis.
#
# <img src="images/camelyon16_example.png" width=300>
#
#
# ### Setting up the working environment
#
# Although you are free to use a programming language and environment of your own choice for the main project work, the examples in the assignments are in Python. If you need to refresh your Python programming skills, we recommend the following educational modules that we have prepared: https://github.com/tueimage/essential-skills.
#
# To get started with setting up a Python environment, follow the instructions in the Getting Started section of the [Essential Skills](https://github.com/tueimage/essential-skills/blob/master/python-essentials.md) Python module. The Anaconda distribution is recommended. Optionally, you can use the desktop GUI called Anaconda Navigator.
#
# To run the complete development environment for this course, you need to install seven additional Python packages: `matplotlib`, `jupyter`, `scikit-learn`, `scipy`, `spyder`, `pandas`, and `tensorflow`. It is recommended to install these packages in a separate Conda environment. A Conda environment is a directory in which you can install files and packages such that their dependencies will not interact with other environments, which is very useful if you develop code for different courses or research projects. If you want to know more about how to use Conda, read the [docs](https://docs.conda.io/projects/conda/en/latest/user-guide/getting-started.html).
#
# After installing Anaconda, you can create a new Conda environment and install the required packages by running the following commands from the Anaconda Prompt application (without the comments):
#
# ````bash
# conda create --name 8p361 python=3.8								 # create a new environment called `8p361`
# conda activate 8p361												 # activate this environment
# conda install matplotlib jupyter scikit-learn scipy spyder pandas    # install the required packages
# pip install tensorflow											   # install tensorflow seperately through pip
# ````
#
# NB: You have to activate the `8p361` environment every time you start working on the assignments (`conda activate 8p361`).
#
# ##### OPTIONAL installation instructions for GPU-support in tensorflow:
# By default, Tensorflow will train the neural networks on the CPU. Training on the CPU is slower than training the neural networks on the GPU. If you want to accelerate your training, these additional advanced steps will allow the neural network to be trained on the GPU, which could save time during training.
#
# Download and install CUDA Toolkit 11.0 https://developer.nvidia.com/cuda-11.0-download-archive, other versions will not work.
#
# Download cuDNN 8.0.4 for CUDA 11.0  https://developer.nvidia.com/rdp/cudnn-archive, other versions will not work. This requires the creation of an account and logging in. To expedite the process you can use a Google account.
#
# After downloading, Put the cuda folder inside the downloaded cuDNN zip file in the following location: `C:\tools\`. If this folder does not exist, create it.
#
# IMPORTANT NOTE: After installing CUDA Toolkit 11.0 you MUST navigate to `C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.0\extras\CUPTI\lib64`, copy the file `cupti64_2020.1.0.dll`, and rename its copy to `cupti64_110.dll`.
#
# Finally, assuming you installed everything in the default locations, you must add some folders to your path variable by searching for `Edit the system environment variables`, clicking `Environment Variables` in the menu that pops up. Select `Path` in the `System variables` box and click `Edit`.
# Once in this menu, ensure that `C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.0\bin`, `C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.0\extras\CUPTI\lib64`, `C:\Program Files\NVIDIA GPU Computing Toolkit\CUDA\v11.0\include`, and `C:\tools\cuda\bin` are added to the path. If not already there, click the 'New' button and add all missing paths in seperate fields.
#
#
#
# ### Literature
#
# [1] LeCun, Y., Bengio, Y., & Hinton, G., 2015. Deep learning. Nature, 521.
#
# [2] Litjens, G., Kooi, T., Bejnordi, B.E., Setio, A.A.A., Ciompi, F., Ghafoorian, M., Van Der Laak, J.A., Van Ginneken, B. and Sánchez, C.I., 2017. A survey on deep learning in medical image analysis. Medical image analysis, 42.
#
# [3] Bejnordi, B. E., Veta, M., Van Diest, P. J., Van Ginneken, B., Karssemeijer, N., Litjens, G., van der Laak, J. A. W. M. ,the CAMELYON16 Consortium, 2017. Diagnostic assessment of deep learning algorithms for detection of lymph node metastases in women with breast cancer. JAMA, 318.
#
# [4] Van Ginneken, B. Why Challenges? https://grand-challenge.org/Why_Challenges
#
# [5] Veta, M., et al., 2015. Assessment of algorithms for mitosis detection in breast cancer histopathology images. Medical image analysis, 20.
#
# [6] Veta, M., et al., 2018. Predicting breast tumor proliferation from whole-slide images: the TUPAC16 challenge. arXiv preprint.
#
# [7] Donegan, W.L., 1997. Tumor‐related prognostic factors for breast cancer. CA: a cancer journal for clinicians, 47.
#
# [8] Madabhushi, A. and Lee, G., 2016. Image analysis and machine learning in digital pathology: Challenges and opportunities. Medical Image Analysis, 33.
#
# [9] Veeling, B., The PatchCamelyon (PCam) deep learning classification benchmark. https://github.com/basveeling/pcam
#
# [10] Histopathologic Cancer Detection. https://www.kaggle.com/c/histopathologic-cancer-detection
#
# ### Before you start with the exercises...
#
# In the exercises below you have to answer some questions relating to topic of the project work. The answers to the questions can be found in the literature list above, however, you are strongly encouraged to expand this list by performing a literature search yourself.
#
# ## Exercise 1
#
# What is the clinical utility of evaluating the presence of metastases in sentinel lymph nodes in breast cancer patients? In other words, how is this information used in the clinical decision making process for breast cancer patients?

# %% [markdown]
# Sentinel lymph nodes (SLNs) are the first lymph nodes “to which cancer cells are most likely to spread from a primary tumor” (Sentinel Lymph Node Biopsy, 2019). Histologic examination of the SLNs can reveal whether metastasis to the SLNs has occurred, and can thus provide an indication of metastasis to more distant sites in the body (Donegan, 1997).  Drainage from the breast is dependent on the site of the tumor, as drainage can occur to both the axillary lymph nodes (ALNs) or the internal mammary lymph nodes (IMLNs) (Estourgie et al., 2004).
# The most indicative predictor for death and posttreatment recurrence in breast cancer is the presence (or absence) of metastasis to the axillary lymph nodes (ALN). The absolute number of involved nodes (e.g. nodes with cancer cells present) can provide a more quantitative answer for recurrence and survival, as the 10-year survival decreases with the number of involved nodes. Not only axillary, but also the IMLNs provide proof for possible metastasis. It has been shown that even when the ALNs are metastasis-free, the IMLNs are involved in nine percent of cases. This indicates that investigation of IMLNs can provide extra information to whether a tumor is locally confined or not (Donegan, 1997).
# Evaluating the presence of metastases in SLNs determines whether axillary lymph node dissection (ALND) is needed. When no metastasis or isolated tumor cells are found, the ALNs can be spared and ALND is not performed. When there is a metastasis present (micro- or macro-metastasis), ALND will take place. This is because for larger metastases, the prevalence of ALN involvement significantly increases. For patients with SLN micro-metastasis, ALND is especially important as patients not undergoing ALND have an increased risk of recurrence. Furthermore, lympho-vascular invasion in primary tumors has been shown to correlate significantly with SLN positivity (Illyes et al., 2014).
#
#
# References
#
# Donegan, W. L. (1997). Tumor-related prognostic factors for breast cancer. CA: A Cancer Journal for Clinicians, 47(1), 28–51. https://doi.org/10.3322/canjclin.47.1.28
#
# Estourgie, S. H., Nieweg, O. E., Valdés Olmos, R. A., Rutgers, E. J. T., & Kroon, B. B. R. (2004). Lymphatic Drainage Patterns from the Breast. Annals of Surgery, 239(2), 232–237. https://doi.org/10.1097/01.sla.0000109156.26378.90
#
# Illyes, I., Tokes, A. M., Kovacs, A., Szasz, A. M., Molnar, B. A., Molnar, I. A., Kaszas, I., Baranyak, Z., Laszlo, Z., Kenessey, I., & Kulka, J. (2014). In breast cancer patients sentinel lymph node metastasis characteristics predict further axillary involvement. Virchows Archiv, 465(1), 15–24. https://doi.org/10.1007/s00428-014-1579-5
#
# Sentinel Lymph Node Biopsy. (2019). National Cancer Institute. https://www.cancer.gov/about-cancer/diagnosis-staging/staging/sentinel-node-biopsy-fact-sheet

# %% [markdown]
# ## Exercise 2
#
# How does the introduction of whole-slide imaging change the typical workflow of a pathology lab?

# %% [markdown]
# Prior to the introduction of whole-slide imaging (WSI), digital imaging in anatomic pathology relied largely on microscope-mounted cameras to produce static digital images. These images were limited in utility because they captured only specific regions of a glass slide. WSI technology was inspired by pioneering efforts to achieve high-resolution scanning of an entire glass slide. Most modern WSI instruments today are capable of producing high-resolution digital slides in the span of minutes (or less) [1].
# WSI has been used for a wide variety of clinical purposes, including telepathology for primary diagnosis, consultation (second opinions), and remotely interpreting frozen sections. Whole slide images have also been used for remotely viewing immunostains, showcasing pathology slides at tumor boards, saving selected consult slides before they are returned, archiving slides before they get sacrificed to use cellular material for molecular studies, and performing image analysis. [2]
# Full digitalization of the microscopic evaluation of stained tissue sections in histopathology has become feasible in recent years because of advances in slide scanning technology and cost reduction in digital storage. Advantages of digital pathology include remote diagnostics, immediate avail- ability of archival cases and easier consultations with expert pathologists. Also, the possibility for computer-aided diagnostics may be advantageous. [3]
# Accurate breast cancer staging is an essential task performed by pathologists worldwide to inform clinical management. Assessing the extent of cancer spread by histopathological analysis of sentinel axillary lymph nodes (SLNs) is an important part of breast cancer staging. The sensitivity of SLN assessment by pathologists, however, is not optimal. A retrospective study showed that pathology review by experts changed the nodal status in 24% of patients. Furthermore, SLN assessment is tedious and time consuming. It has been shown that deep learning algorithms could identify metastases in SLN slides with 100% sensitivity, whereas 40% of the slides without metastases could be identified as such. This could result in a significant reduction in the workload of pathologists. [3]
#
#
# [1]	L. Pantanowitz et al., “Review of the current state of whole slide imaging in pathology,” J. Pathol. Inform., vol. 2, no. 1, p. 36, 2011, doi: 10.4103/2153-3539.83746.
#
# [2]	N. Farahani, A. V Parwani, and L. Pantanowitz, “Whole slide imaging in pathology : advantages , limitations , and emerging perspectives,” Pathol. Lab. Med. Int., vol. 7, pp. 23–33, 2015.
#
# [3]	B. E. Bejnordi et al., “Diagnostic assessment of deep learning algorithms for detection of lymph node metastases in women with breast cancer,” JAMA - J. Am. Med. Assoc., vol. 318, no. 22, pp. 2199–2210, Dec. 2017, doi: 10.1001/JAMA.2017.14585.

# %% [markdown]
# ## Exercise 3
#
# The PatchCamelyon dataset is derived from the CAMELYON16 dataset of whole-slide images. Describe how a neural network classification model trained on small image patches can be applied to larger, whole-slide images with the goal of detecting metastases.

# %% [markdown]
# A gigapixel scale whole-slide image (WSI) can not be easily analyzed due to the immeasurable computational cost [2], in such it can be split up in small image patches, which can be used to train a neural network classification model.
# Furthermore the differentiation of cancer subtypes is based on cellular-level visual features observed on image patch scale [1]. All features that are necessary for detection, and recognition, of metastases can be found in images the size of patches.
# Division of a WSI into small patches, and subsequent determination of metastase presence for each of these patches is a WSI patch-by-patch analyzing method for metastases. The results of this method can be combined to fully analyze a WSI for metastase presence; If all subdivisions of a WSI show no metastase it can be concluded that the tissue Is healthy. If some subdivisions show metastases according to the model, it can be concluded that metastases are present in the WSI.
# A heatmap of metastase prediction level per patch on the WSI could also be generated to aid in diagnosis.
#
# 1.	https://www.cv-foundation.org/openaccess/content_cvpr_2016/papers/Hou_Patch-Based_Convolutional_Neural_CVPR_2016_paper.pdf
# 2.	https://openreview.net/forum?id=SJwod1hjz

# %% [markdown]
# ## Exercise 4
#
# Download and unzip the [training and validation (4 GB)](https://drive.google.com/file/d/1nK9H2ldvGQL9LAIOYk3E8nD9kUri_Ly4/view?usp=sharing), and [testing (1 GB)](https://drive.google.com/file/d/13i66bWie00tt6LuhLPzoZ8pBPJ9ZFIXf/view?usp=sharing) subsets of the Patch-CAMELYON dataset. Note that the unzipping process might take a while due to the large number of files in the archives.
#
# Write a small Python script that reads and displays a few images from the two classes. Visually describe and compare the appearance of the tissue in the patches with and without metastases.

# %%
### Python script that reads and displays a few images from the two classes. ###
import os, random
import matplotlib.pyplot as plt
pad_0 = r"C:\Users\20192735\Documents\8P361 - images\train\0"
pad_1 = r"C:\Users\20192735\Documents\8P361 - images\train\1"
pad = r"C:\Users\20192735\Documents\8P361 - images\train"
filenames = [[], []]
num_samples = 6
while len(filenames[0]) != num_samples or len(filenames[1]) != num_samples:
    if len(filenames[0]) != num_samples:
        file_0 = random.choice(os.listdir(pad_0)) 
        if file_0 not in filenames[0]:
            filenames[0].append(file_0)
    if len(filenames[1]) != num_samples:
        file_1 = random.choice(os.listdir(pad_1))
        if file_1 not in filenames[1]:
            filenames[1].append(file_1)
  
print(filenames)  
fig = plt.figure(figsize=(15,5))
for i in range(num_samples):
    img_0 = plt.imread(pad_0+"\\"+filenames[0][i])
    ax = fig.add_subplot(2, num_samples, i+1, frameon=False)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_title('0')
    plt.imshow(img_0)
    
    img_1 = plt.imread(pad_1+"\\"+filenames[1][i])
    ax = fig.add_subplot(2, num_samples, i+num_samples+1, frameon=False)
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.set_title('1')
    plt.imshow(img_1)    
    
    
plt.savefig(r"C:\Users\20192735\OneDrive - TU Eindhoven\8P361 - Project Imaging\8p361-project-imaging-master\assignments\Lymph nodes.png")
plt.show()
# Out:
# [['a84122b38d4fb4af245f69dff1f0e22e344faeb8.jpg', '74d69f8d138db2fa173c248de8acb98ef07f1af1.jpg', '9e9274897e04d4a65c3b855a52ccc25d6c618b1a.jpg', '354e49eece0a05de57fcea9452cf9a36179c1168.jpg', 'f7137134218f52fd9e2a790d8a6f5337b0e87c95.jpg', 'c8fa2da87ad10ddcabd765a1db6d76f5bb51f609.jpg'], ['fc43d0cf3408457d04081189a794fc10e815a1ee.jpg', '666280e470a2e5add0b60e19770f726c073cb4b3.jpg', '8ac2476ef63fc6e737d906a34ceb1e2d89f31aff.jpg', '6adf2f70ab17edf89f669fe7dcdcf1c3efc9b1e1.jpg', '27b29873a518f8e91b131289fe3e281957f5a1f4.jpg', 'b66b8371b7f84f1d82ca2c4683ac44c16e52845e.jpg']]

# %% [markdown]
# The patches of cells under 0, without metastases, are normal cells. Normally sized nuclei and sometimes a big white area in the image. The patches of cells under 1, with metastases, are visually different. Bigger nuclei and weird shaped cells.

# %% [markdown]
# ##  Exercise 5
#
# Make an account on Kaggle and subscribe to the Patch-CAMELYON challenge. You will use this account to submit results for evaluation from your main project work. You can also make accounts for every team member and submit results as a team. Note that you do not have to download the dataset again from Kaggle (the version that we have prepared is a bit easier to work with and can still be used to submit results).

# %% [markdown]
# Usernames of our teammembers:<br>
# •	colinschrijver <br>
# •	RobinvanVelzen1<br>
# •	larsdaenen<br>
# •	bramboerenkamp

# %% [markdown]
# ## Submission checklist
#
# - Exercise 1: Answers to the questions
# - Exercise 2: Answers to the questions
# - Exercise 3: Answers to the questions
# - Exercise 4: Answers to the questions and code
# - Exercise 5: Kaggle username or team name
